# %%
# Test the create_microsplit_configuration function that fails in doctest on GitHub
from src.careamics.config import create_microsplit_configuration

# This is the exact same call as in the doctest
config = create_microsplit_configuration(
    experiment_name="microsplit_experiment",
    data_type="array",
    axes="YX",
    patch_size=[64, 64],
    batch_size=32,
    num_epochs=100,
    nm_paths=["/path/to/nm1", "/path/to/nm2"]
)

print("Configuration created successfully!")
print(f"Experiment name: {config.experiment_name}")
print(f"Algorithm: {config.algorithm_config.algorithm}")
print(f"Data type: {config.data_config.data_type}")
print(f"Axes: {config.data_config.axes}")
print(f"Patch size: {config.data_config.patch_size}")
print(f"Batch size: {config.data_config.batch_size}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 from src.careamics.config import create_microsplit_configuration
#       4 # This is the exact same call as in the doctest
# ----> 5 config = create_microsplit_configuration(
#       6     experiment_name="microsplit_experiment",
#       7     data_type="array",
#       8     axes="YX",
#       9     patch_size=[64, 64],
#      10     batch_size=32,
#      11     num_epochs=100,
#      12     nm_paths=["/path/to/nm1", "/path/to/nm2"]
#      13 )
#      15 print("Configuration created successfully!")
#      16 print(f"Experiment name: {config.experiment_name}")
#
# ...
